# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/index-and-multiindex](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/index-and-multiindex)
#
# ---
#
# Import Pandas and NumPy for the notebook:
