# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/dealing-with-missing-data-duplicates](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/dealing-with-missing-data-duplicates)
#
# ---
#
# Import Pandas and NumPy for the notebook:
