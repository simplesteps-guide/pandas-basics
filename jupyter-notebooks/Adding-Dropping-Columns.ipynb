# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/adding-and-dropping-columns](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/adding-and-dropping-columns)
#
# ---
#
# Import Pandas for the notebook:

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Adding and Dropping Columns
#
# ### Adding
#
# Assign the same value to every row:

# %%
df = pd.DataFrame({"A": [1, 2, 3]})
df["B"] = 10
df
# Out:
#    A   B
# 0  1  10
# 1  2  10
# 2  3  10

# %% [markdown]
# Assigning a list or array:

# %%
df["C"] = [100, 200, 300]
df
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  10  200
# 2  3  10  300

# %% [markdown]
# Using calculations on existing columns:

# %%
df["D"] = df["A"] + df["C"]
df
# Out:
#    A   B    C    D
# 0  1  10  100  101
# 1  2  10  200  202
# 2  3  10  300  303

# %% [markdown]
# Using .assign():

# %%
df = df.assign(E=df["D"] * 2)
df
# Out:
#    A   B    C    D    E
# 0  1  10  100  101  202
# 1  2  10  200  202  404
# 2  3  10  300  303  606

# %% [markdown]
# Using .insert():

# %%
df.insert(1, "F", [7, 8, 9])
df
# Out:
#    A  F   B    C    D    E
# 0  1  7  10  100  101  202
# 1  2  8  10  200  202  404
# 2  3  9  10  300  303  606

# %% [markdown]
# ---
#
# ### Dropping
#
# Using .drop():

# %%
df.drop("B", axis=1, inplace=True) 
df
# Out:
#    A  F    C    D    E
# 0  1  7  100  101  202
# 1  2  8  200  202  404
# 2  3  9  300  303  606

# %% [markdown]
# Drop multiple columns:

# %%
df.drop(["C", "D"], axis=1, inplace=True)
df
# Out:
#    A  F    E
# 0  1  7  202
# 1  2  8  404
# 2  3  9  606

# %% [markdown]
# Using del:

# %%
del df["F"]
df
# Out:
#    A    E
# 0  1  202
# 1  2  404
# 2  3  606

# %% [markdown]
# Using .pop()

# %%
popped_column = df.pop("E")
popped_column
# Out:
# 0    202
# 1    404
# 2    606
# Name: E, dtype: int64

# %%
df
# Out:
#    A
# 0  1
# 1  2
# 2  3
