# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/data-exploration](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/data-exploration)
#
# ---
#
# Import Pandas and NumPy for the notebook:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load in some sample data:

# %%
df = pd.read_csv('../datafiles/data-extra.csv', index_col='ID')
df
# Out:
#        Name  Age         City Country  Salary
# ID
# 1     Alice   25     New York     USA   50000
# 2       Bob   30  Los Angeles     USA   60000
# 3   Charlie   35      Chicago     USA   55000
# 4     David   40      Houston     USA   65000

# %% [markdown]
# ---
# ## **Data Exploration**
#
# **.info()**:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
#  1   Age      4 non-null      int64
#  2   City     4 non-null      object
#  3   Country  4 non-null      object
#  4   Salary   4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 192.0+ bytes

# %% [markdown]
# **.head()**:

# %%
df.head(2)
# Out:
#      Name  Age         City Country  Salary
# ID
# 1   Alice   25     New York     USA   50000
# 2     Bob   30  Los Angeles     USA   60000

# %% [markdown]
# **.tail()**:

# %%
df.tail(3)
# Out:
#        Name  Age         City Country  Salary
# ID
# 2       Bob   30  Los Angeles     USA   60000
# 3   Charlie   35      Chicago     USA   55000
# 4     David   40      Houston     USA   65000

# %% [markdown]
# **.shape**:

# %%
df.shape
# Out:
# (4, 5)

# %% [markdown]
# **.dtypes**:

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# City       object
# Country    object
# Salary      int64
# dtype: object

# %% [markdown]
# **.columns**:

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %% [markdown]
# Create some more test data for the next examples:

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Eve", "Bob"],
    "Department": ["HR", "IT", "Finance", "HR", "IT", "Finance"],
    "Age": [25, 30, 35, 25, 40, 30]
}

df2 = pd.DataFrame(data)
df2
# Out:
#       Name Department  Age
# 0    Alice         HR   25
# 1      Bob         IT   30
# 2  Charlie    Finance   35
# 3    Alice         HR   25
# 4      Eve         IT   40
# 5      Bob    Finance   30

# %% [markdown]
# **.unique()**:

# %%
df2['Department'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %% [markdown]
# **.nunique()**:

# %%
df2['Department'].nunique()
# Out:
# 3

# %% [markdown]
# **.value_counts()**:

# %%
df2['Department'].value_counts()
# Out:
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %% [markdown]
# **.describe()**:

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   32.500000  57500.000000
# std     6.454972   6454.972244
# min    25.000000  50000.000000
# 25%    28.750000  53750.000000
# 50%    32.500000  57500.000000
# 75%    36.250000  61250.000000
# max    40.000000  65000.000000

# %% [markdown]
# Create some more sample data for demoing corr

# %%
data2 = {
    "Math_Score": [88, 92, 80, 89, 100, 67, 78, 85],
    "Science_Score": [90, 95, 70, 88, 98, 65, 75, 82],
    "English_Score": [85, 80, 78, 90, 93, 70, 72, 88],
    "Study_Hours": [10, 12, 6, 9, 15, 4, 5, 8]
}

df3 = pd.DataFrame(data2)
df3
# Out:
#    Math_Score  Science_Score  English_Score  Study_Hours
# 0          88             90             85           10
# 1          92             95             80           12
# 2          80             70             78            6
# 3          89             88             90            9
# 4         100             98             93           15
# 5          67             65             70            4
# 6          78             75             72            5
# 7          85             82             88            8

# %% [markdown]
# **.corr()**:

# %%
df3.corr()
# Out:
#                Math_Score  Science_Score  English_Score  Study_Hours
# Math_Score       1.000000       0.951769       0.848767     0.954129
# Science_Score    0.951769       1.000000       0.773652     0.951102
# English_Score    0.848767       0.773652       1.000000     0.776552
# Study_Hours      0.954129       0.951102       0.776552     1.000000

# %% [markdown]
# Create some sample data for demoing null values

# %%
data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, np.nan, 35, 40, np.nan],
    "Department": ["HR", "IT", np.nan, "Finance", "IT"],
    "Salary": [50000, 60000, 70000, np.nan, 65000]
}

df4 = pd.DataFrame(data3)
df4
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob   NaN         IT  60000.0
# 2  Charlie  35.0        NaN  70000.0
# 3    David  40.0    Finance      NaN
# 4      Eve   NaN         IT  65000.0

# %% [markdown]
# **.isna()**:

# %%
df4.isna().sum()
# Out:
# Name          0
# Age           2
# Department    1
# Salary        1
# dtype: int64

# %% [markdown]
# **.sample(n)**:

# %%
df.sample(3)
# Out:
#        Name  Age      City Country  Salary
# ID
# 1     Alice   25  New York     USA   50000
# 3   Charlie   35   Chicago     USA   55000
# 4     David   40   Houston     USA   65000
