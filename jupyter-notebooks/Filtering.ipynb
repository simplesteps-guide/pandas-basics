# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/filtering](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/filtering)
#
# ---
#
# Import Pandas and NumPy for the notebook:
