# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/concatenate-merge-join](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/concatenate-merge-join)
#
# ---
#
# Import Pandas for the notebook:

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Concatenate, Merge & Join
#
# Concatenate:

# %%
df1 = pd.DataFrame({"A": [1, 2], "B": [3, 4]})
df2 = pd.DataFrame({"A": [5, 6], "B": [7, 8]})

pd.concat([df1, df2], ignore_index=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8

# %% [markdown]
# Merge (pd.merge):

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Alice", "Bob", "Charlie"]})
df2 = pd.DataFrame({"ID": [2, 3, 4], "Salary": [50000, 60000, 70000]})

pd.merge(df1, df2, on="ID", how="inner")
# Out:
#    ID     Name  Salary
# 0   2      Bob   50000
# 1   3  Charlie   60000

# %% [markdown]
# Join (df.join):

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"], "ID": [1, 2]}).set_index("ID")
df2 = pd.DataFrame({"Salary": [50000, 60000]}, index=[1, 2])

df1.join(df2)
# Out:
#      Name  Salary
# ID
# 1   Alice   50000
# 2     Bob   60000
