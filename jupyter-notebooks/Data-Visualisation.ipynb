# %% [markdown]
# Examples for [https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/data-visualisation-using-plot](https://simplesteps.guide/guides/technology/machine-learning-ai/pandas-basics/data-visualisation-using-plot)
#
# ---
#
# Import Pandas and NumPy for the notebook:
